# %%
import os
from dotenv import load_dotenv
from groq import Groq

# Load environment variables
load_dotenv()

# Configure Groq
api_key = os.getenv("GROQ_API_KEY")
client = Groq(api_key=api_key)

# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
assistant.rag("I just discovered the course, can I still join?")
# Out:
# 'Yes, you can still join.  If you want to receive a certificate, you need to submit your project within the timeframe for accepting submissions.'
